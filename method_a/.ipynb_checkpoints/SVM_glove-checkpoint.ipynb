# %% [markdown]
# # Libraries

# %%
# !pip install scikit-learn
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !pip install torchtext==0.6.0
# !pip install transformers sentence-transformers
# !pip install tqdm
# Out:
# Requirement already satisfied: transformers in d:\programming\anaconda\envs\nlu\lib\site-packages (4.39.2)
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: filelock in d:\programming\anaconda\envs\nlu\lib\site-packages (from transformers) (3.13.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in d:\programming\anaconda\envs\nlu\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in d:\programming\anaconda\envs\nlu\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\programming\anaconda\envs\nlu\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\programming\anaconda\envs\nlu\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in d:\programming\anaconda\envs\nlu\lib\site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in d:\programming\anaconda\envs\nlu\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in d:\programming\anaconda\envs\nlu\lib\site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in d:\programming\anaconda\envs\nlu\lib\site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in d:\programming\anaconda\envs\nlu\lib\site-packages (from transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in d:\programming\anaconda\envs\nlu\lib\site-packages (from sentence-transformers) (2.2.2+cu118)
# Requirement already satisfied: scikit-learn in d:\programming\anaconda\envs\nlu\lib\site-packages (from sentence-transformers) (1.4.1.post1)
# Requirement already satisfied: scipy in d:\programming\anaconda\envs\nlu\lib\site-packages (from sentence-transformers) (1.12.0)
# Requirement already satisfied: Pillow in d:\programming\anaconda\envs\nlu\lib\site-packages (from sentence-transformers) (10.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\programming\anaconda\envs\nlu\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\programming\anaconda\envs\nlu\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: sympy in d:\programming\anaconda\envs\nlu\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in d:\programming\anaconda\envs\nlu\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in d:\programming\anaconda\envs\nlu\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: colorama in d:\programming\anaconda\envs\nlu\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\programming\anaconda\envs\nlu\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\programming\anaconda\envs\nlu\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\programming\anaconda\envs\nlu\lib\site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\programming\anaconda\envs\nlu\lib\site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: joblib>=1.2.0 in d:\programming\anaconda\envs\nlu\lib\site-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\programming\anaconda\envs\nlu\lib\site-packages (from scikit-learn->sentence-transformers) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\programming\anaconda\envs\nlu\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in d:\programming\anaconda\envs\nlu\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#    ---------------------------------------- 0.0/171.5 kB ? eta -:--:--
#    ------- -------------------------------- 30.7/171.5 kB 1.3 MB/s eta 0:00:01
#    --------------------- ------------------ 92.2/171.5 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 171.5/171.5 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.7.0

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import classification_report
import re
import string
from torchtext.vocab import GloVe
import torch
from torchtext import data
import spacy
import random
from joblib import dump, load

# %% [markdown]
# # Read Data

# %%
train_data = pd.read_csv('train.csv')
val_data = pd.read_csv('dev.csv')

# %% [markdown]
# # Tokenisation

# %%
tokens = []
count = 0
num_inv = 0
num_oov = 0
glove_mode = True

update_inv_mode = False
update_oov_mode = False
word_mode = (glove_mode, update_inv_mode, update_oov_mode)

# %%
# Load SpaCy English tokenizer
spacy_en = spacy.load('en_core_web_sm')
inputs = data.Field(lower=True, tokenize=lambda text: [token.text for token in spacy_en.tokenizer(text)])

# %%
train_data['processed_premise'] = train_data['premise'].astype(str).apply(inputs.preprocess)
train_data['processed_hypothesis'] = train_data['hypothesis'].astype(str).apply(inputs.preprocess)

val_data['processed_premise'] = val_data['premise'].astype(str).apply(inputs.preprocess)
val_data['processed_hypothesis'] = val_data['hypothesis'].astype(str).apply(inputs.preprocess)

# %% [markdown]
# # Embedding

# %%
# Load GloVe embeddings
EMBEDDING_DIM = 300
glove = GloVe(name='840B', dim=EMBEDDING_DIM) # Using GloVe with 840 billion tokens and 300 dimensions

# GloVe's vocabulary and vectors
wv_dict = glove.stoi  # Word to index mapping
wv_arr = glove.vectors  # Embedding matrix
wr_size = glove.dim  # Embedding dimension

# %%
def embedding(tokens):
    embeddings = torch.zeros(300)
    for word in tokens:
        if word in wv_dict:
            embeddings += wv_arr[wv_dict[word]]
        else:
            embeddings += torch.Tensor([random.uniform(-0.05, 0.05) for i in range(EMBEDDING_DIM)])
    embeddings = embeddings / len(tokens)
    return embeddings
    
train_data['premise_vec'] = train_data['processed_premise'].apply(embedding)
train_data['hypothesis_vec'] = train_data['processed_hypothesis'].apply(embedding)

val_data['premise_vec'] = val_data['processed_premise'].apply(embedding)
val_data['hypothesis_vec'] = val_data['processed_hypothesis'].apply(embedding)

# %%
stacked_tensors = []
for index, row in train_data.iterrows():
    vector1 = row['premise_vec']
    vector2 = row['hypothesis_vec']

    stacked_tensor = torch.concatenate((vector1, vector2), dim=0)
    
    stacked_tensors.append(stacked_tensor)
train_data['combined_vector'] = stacked_tensors

stacked_tensors = []
for index, row in val_data.iterrows():
    vector1 = row['premise_vec']
    vector2 = row['hypothesis_vec']

    stacked_tensor = torch.concatenate((vector1, vector2), dim=0)
    
    stacked_tensors.append(stacked_tensor)
val_data['combined_vector'] = stacked_tensors

# %% [markdown]
# # SVM

# %%
# Bootstrapping
X_train, y_train = np.array(train_data["combined_vector"].tolist()), np.array(train_data["label"].tolist())
# X_bootstrap_samples = {}
# y_bootstrap_samples = {}

# for i in range(3):
#     n_samples = len(X_train)
    
#     bootstrap_indices = np.random.randint(0, n_samples, size=n_samples)
    
#     X_bootstrap_samples[f'X_train_{i+1}'] = X_train[bootstrap_indices]
#     y_bootstrap_samples[f'y_train_{i+1}'] = y_train[bootstrap_indices]

X_val, y_val = val_data["combined_vector"].tolist(), val_data["label"].tolist()

# %% [markdown]
# ## First

# %%
svm_1 = SVC(kernel='rbf', C=1) 
svm_1.fit(X_bootstrap_samples['X_train_1'], y_bootstrap_samples['y_train_1'])
# Out:
# SVC(C=1)

# %%
# Evaluate
y_pred_1 = svm_1.predict(X_val)
print(classification_report(y_val, y_pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.55      0.61      3259
#            1       0.64      0.75      0.69      3478
#
#     accuracy                           0.65      6737
#    macro avg       0.66      0.65      0.65      6737
# weighted avg       0.66      0.65      0.65      6737

# %% [markdown]
# ## Second

# %%
svm_2 = SVC(kernel='rbf', C=1) 
svm_2.fit(train_data["combined_vector"].tolist(), train_data['label'].tolist())

# Evaluate
y_pred_2 = svm_2.predict(X_val)
print(classification_report(y_val, y_pred_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.56      0.62      3259
#            1       0.65      0.76      0.70      3478
#
#     accuracy                           0.66      6737
#    macro avg       0.67      0.66      0.66      6737
# weighted avg       0.67      0.66      0.66      6737

# %% [markdown]
# ## Third

# %%
svm_3 = SVC(kernel='rbf', C=3.5) 
svm_3.fit(train_data["combined_vector"].tolist(), train_data['label'].tolist())

# Evaluate
y_pred_3 = svm_3.predict(X_val)
print(classification_report(y_val, y_pred_3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.59      0.64      3259
#            1       0.66      0.76      0.71      3478
#
#     accuracy                           0.67      6737
#    macro avg       0.68      0.67      0.67      6737
# weighted avg       0.68      0.67      0.67      6737

# %%
svm_4 = SVC(kernel='rbf', C=3) 
svm_4.fit(train_data["combined_vector"].tolist(), train_data['label'].tolist())

# Evaluate
y_pred_4 = svm_4.predict(X_val)
print(classification_report(y_val, y_pred_4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.59      0.64      3259
#            1       0.66      0.76      0.71      3478
#
#     accuracy                           0.68      6737
#    macro avg       0.68      0.67      0.67      6737
# weighted avg       0.68      0.68      0.67      6737

# %%
dump(svm_4, 'svm_glove.joblib')
# Out:
# ['svm_glove.joblib']

# %%
y_pred_combined = (y_pred_1*0.5 + y_pred_2 + y_pred_3 + y_pred_4*3) / 5.5
y_pred_final = np.where(y_pred_combined >= 0.5, 1, 0)
print(classification_report(y_val, y_pred_final))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.59      0.64      3259
#            1       0.66      0.76      0.71      3478
#
#     accuracy                           0.68      6737
#    macro avg       0.68      0.67      0.67      6737
# weighted avg       0.68      0.68      0.67      6737

# %%
df = pd.DataFrame({"prediction": y_pred_1,
                  "prediction2": y_pred_2,
                  "prediction3": y_pred_3,
                  "prediction4": y_pred_4})
df.to_csv('result.csv', index=False)

# %%
df = pd.DataFrame({"prediction": y_pred_final})
df.to_csv('result.csv', index=False)
